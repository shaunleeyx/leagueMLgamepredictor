# %%
from tensorflow import keras
import pandas as pd
import numpy as np
from pandas import read_csv
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)
  
filename = "../riot_api/data.csv"

# %%
def load_dataset(filename):
	# load the dataset as a pandas DataFrame
	data = read_csv(filename, header=None)
	# retrieve numpy array
	dataset = data.values
	# split into input (X) and output (y) variables
	X = dataset[:, :-1]
	y = dataset[:,-1]
	# format all fields as string
	X = X.astype(str)
	# reshape target to be a 2d array
	y = y.reshape((len(y), 1))
	return X, y

# %%
X,y = load_dataset(filename)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.ravel(), test_size=0.33, random_state=1)

# %%
# prepare input data
def prepare_inputs(X_train, X_test):
	oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
	oe.fit(X_train)
	X_train_enc = oe.transform(X_train)
	X_test_enc = oe.transform(X_test)
	return X_train_enc, X_test_enc

# %%
# prepare target
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# %%
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# %%
# define the model
model = Sequential()
model.add(Dense(10, input_dim=X_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/100
# 3/3 - 0s - loss: 2.9013 - accuracy: 0.7083 - 394ms/epoch - 131ms/step
# Epoch 2/100
# 3/3 - 0s - loss: 2.7843 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 3/100
# 3/3 - 0s - loss: 2.7088 - accuracy: 0.7292 - 5ms/epoch - 2ms/step
# Epoch 4/100
# 3/3 - 0s - loss: 2.6313 - accuracy: 0.7292 - 6ms/epoch - 2ms/step
# Epoch 5/100
# 3/3 - 0s - loss: 2.5570 - accuracy: 0.7292 - 4ms/epoch - 1ms/step
# Epoch 6/100
# 3/3 - 0s - loss: 2.4736 - accuracy: 0.7292 - 6ms/epoch - 2ms/step
# Epoch 7/100
# 3/3 - 0s - loss: 2.3966 - accuracy: 0.7292 - 6ms/epoch - 2ms/step
# Epoch 8/100
# 3/3 - 0s - loss: 2.3230 - accuracy: 0.7083 - 6ms/epoch - 2ms/step
# Epoch 9/100
# 3/3 - 0s - loss: 2.2557 - accuracy: 0.7083 - 6ms/epoch - 2ms/step
# Epoch 10/100
# 3/3 - 0s - loss: 2.1761 - accuracy: 0.7083 - 6ms/epoch - 2ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 2.1289 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 2.0658 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 1.9968 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 1.9418 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 1.8944 - accuracy: 0.6875 - 4ms/epoch - 1ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 1.8403 - accuracy: 0.6875 - 6ms/epoch - 2ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 1.7960 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 1.7506 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 1.7047 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 1.6590 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 1.6133 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 1.5670 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 1.5164 - accuracy: 0.6875 - 6ms/epoch - 2ms/step
# Epoch 24/100
# 3/3 - 0s - loss: 1.4824 - accuracy: 0.6875 - 6ms/epoch - 2ms/step
# Epoch 25/100
# 3/3 - 0s - loss: 1.4294 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 26/100
# 3/3 - 0s - loss: 1.3888 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 27/100
# 3/3 - 0s - loss: 1.3535 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 28/100
# 3/3 - 0s - loss: 1.3111 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 29/100
# 3/3 - 0s - loss: 1.2749 - accuracy: 0.6875 - 6ms/epoch - 2ms/step
# Epoch 30/100
# 3/3 - 0s - loss: 1.2330 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 31/100
# 3/3 - 0s - loss: 1.2023 - accuracy: 0.6875 - 7ms/epoch - 2ms/step
# Epoch 32/100
# 3/3 - 0s - loss: 1.1667 - accuracy: 0.6875 - 4ms/epoch - 1ms/step
# Epoch 33/100
# 3/3 - 0s - loss: 1.1325 - accuracy: 0.6875 - 5ms/epoch - 2ms/step
# Epoch 34/100
# 3/3 - 0s - loss: 1.1020 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 35/100
# 3/3 - 0s - loss: 1.0721 - accuracy: 0.7083 - 6ms/epoch - 2ms/step
# Epoch 36/100
# 3/3 - 0s - loss: 1.0469 - accuracy: 0.7083 - 5ms/epoch - 2ms/step
# Epoch 37/100
# 3/3 - 0s - loss: 1.0216 - accuracy: 0.7292 - 6ms/epoch - 2ms/step
# Epoch 38/100
# 3/3 - 0s - loss: 0.9978 - accuracy: 0.7500 - 5ms/epoch - 2ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.9742 - accuracy: 0.7500 - 5ms/epoch - 2ms/step
# Epoch 40/100
# 3/3 - 0s - loss: 0.9478 - accuracy: 0.7500 - 7ms/epoch - 2ms/step
# Epoch 41/100
# 3/3 - 0s - loss: 0.9249 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.9056 - accuracy: 0.7500 - 5ms/epoch - 2ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.8824 - accuracy: 0.7500 - 7ms/epoch - 2ms/step
# Epoch 44/100
# 3/3 - 0s - loss: 0.8600 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.8448 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.8230 - accuracy: 0.7500 - 7ms/epoch - 2ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.8054 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.7843 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.7662 - accuracy: 0.7500 - 6ms/epoch - 2ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.7502 - accuracy: 0.7500 - 14ms/epoch - 5ms/step
# Epoch 51/100
# 3/3 - 0s - loss: 0.7342 - accuracy: 0.7500 - 18ms/epoch - 6ms/step
# Epoch 52/100
# 3/3 - 0s - loss: 0.7159 - accuracy: 0.7708 - 7ms/epoch - 2ms/step
# Epoch 53/100
# 3/3 - 0s - loss: 0.7002 - accuracy: 0.7917 - 7ms/epoch - 2ms/step
# Epoch 54/100
# 3/3 - 0s - loss: 0.6854 - accuracy: 0.7917 - 7ms/epoch - 2ms/step
# Epoch 55/100
# 3/3 - 0s - loss: 0.6706 - accuracy: 0.7917 - 6ms/epoch - 2ms/step
# Epoch 56/100
# 3/3 - 0s - loss: 0.6553 - accuracy: 0.7917 - 11ms/epoch - 4ms/step
# Epoch 57/100
# 3/3 - 0s - loss: 0.6419 - accuracy: 0.7917 - 8ms/epoch - 3ms/step
# Epoch 58/100
# 3/3 - 0s - loss: 0.6258 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 59/100
# 3/3 - 0s - loss: 0.6111 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 60/100
# 3/3 - 0s - loss: 0.5959 - accuracy: 0.8125 - 7ms/epoch - 2ms/step
# Epoch 61/100
# 3/3 - 0s - loss: 0.5816 - accuracy: 0.8125 - 8ms/epoch - 3ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.5708 - accuracy: 0.8125 - 9ms/epoch - 3ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.5559 - accuracy: 0.8125 - 10ms/epoch - 3ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 0.5448 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 0.5349 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.5207 - accuracy: 0.7917 - 8ms/epoch - 3ms/step
# Epoch 67/100
# 3/3 - 0s - loss: 0.5119 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.5002 - accuracy: 0.7917 - 10ms/epoch - 3ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.4928 - accuracy: 0.7917 - 9ms/epoch - 3ms/step
# Epoch 70/100
# 3/3 - 0s - loss: 0.4810 - accuracy: 0.8125 - 8ms/epoch - 3ms/step
# Epoch 71/100
# 3/3 - 0s - loss: 0.4728 - accuracy: 0.7917 - 8ms/epoch - 3ms/step
# Epoch 72/100
# 3/3 - 0s - loss: 0.4633 - accuracy: 0.8125 - 9ms/epoch - 3ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.4541 - accuracy: 0.8333 - 8ms/epoch - 3ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.4445 - accuracy: 0.8333 - 8ms/epoch - 3ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.4365 - accuracy: 0.8333 - 8ms/epoch - 3ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.4285 - accuracy: 0.8333 - 9ms/epoch - 3ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.4216 - accuracy: 0.8333 - 6ms/epoch - 2ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.4132 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.4064 - accuracy: 0.8333 - 6ms/epoch - 2ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.3994 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.3929 - accuracy: 0.8333 - 9ms/epoch - 3ms/step
# Epoch 82/100
# 3/3 - 0s - loss: 0.3865 - accuracy: 0.8333 - 6ms/epoch - 2ms/step
# Epoch 83/100
# 3/3 - 0s - loss: 0.3811 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 84/100
# 3/3 - 0s - loss: 0.3747 - accuracy: 0.8333 - 8ms/epoch - 3ms/step
# Epoch 85/100
# 3/3 - 0s - loss: 0.3693 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 86/100
# 3/3 - 0s - loss: 0.3643 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 87/100
# 3/3 - 0s - loss: 0.3587 - accuracy: 0.8333 - 7ms/epoch - 2ms/step
# Epoch 88/100
# 3/3 - 0s - loss: 0.3538 - accuracy: 0.8542 - 7ms/epoch - 2ms/step
# Epoch 89/100
# 3/3 - 0s - loss: 0.3491 - accuracy: 0.8542 - 7ms/epoch - 2ms/step
# Epoch 90/100
# 3/3 - 0s - loss: 0.3443 - accuracy: 0.8542 - 7ms/epoch - 2ms/step
# Epoch 91/100
# 3/3 - 0s - loss: 0.3402 - accuracy: 0.8542 - 7ms/epoch - 2ms/step
# Epoch 92/100
# 3/3 - 0s - loss: 0.3355 - accuracy: 0.8542 - 8ms/epoch - 3ms/step
# Epoch 93/100
# 3/3 - 0s - loss: 0.3313 - accuracy: 0.8542 - 8ms/epoch - 3ms/step
# Epoch 94/100
# 3/3 - 0s - loss: 0.3277 - accuracy: 0.8542 - 5ms/epoch - 2ms/step
# Epoch 95/100
# 3/3 - 0s - loss: 0.3237 - accuracy: 0.8542 - 7ms/epoch - 2ms/step
# Epoch 96/100
# 3/3 - 0s - loss: 0.3206 - accuracy: 0.8542 - 5ms/epoch - 2ms/step
# Epoch 97/100
# 3/3 - 0s - loss: 0.3152 - accuracy: 0.8542 - 6ms/epoch - 2ms/step
# Epoch 98/100
# 3/3 - 0s - loss: 0.3126 - accuracy: 0.8542 - 9ms/epoch - 3ms/step
# Epoch 99/100
# 3/3 - 0s - loss: 0.3087 - accuracy: 0.8542 - 6ms/epoch - 2ms/step
# Epoch 100/100
# 3/3 - 0s - loss: 0.3080 - accuracy: 0.8542 - 6ms/epoch - 2ms/step
# Accuracy: 62.50
